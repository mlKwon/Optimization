# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
import seaborn as sns
from collections import Counter
from copy import deepcopy as dc
from itertools import chain
from sympy import Derivative, symbols

# %% [markdown]
# $f(x) = (x_1 + x_2)^2 + 3$ <br>
# $subject \,to $ <br>
#     $\quad g1(x) = x_1 + x_2 >= 5$ <br>
#     $\quad g2(x) = 2x_1 + 3x_2 <= 12$ <br>
#     $\quad x_1>=0, x_2>=0$

# %% [markdown]
# $It \; can \; be \; defined \; as$ <br>
# $f(x) = (x_1 + x_2)^2 + 3$ <br><br>
# $subject \,to $ <br>
#     $\quad h_1(x) = x_1 + x_2 - s_1= 5$ <br>
#     $\quad h_2(x) = 2x_1 + 3x_2 + s_2= 12$ <br>
#     $\quad x_1>=0, x_2>=0, s_1>=0, s_2>=0$

# %% [markdown]
# step 1

# %%
# define objective and constrain function
def f(x1,x2):
    return x1*x1 + x2*x2 + 2*x1*x2 + 3

def h1(x1,x2,s1):
    return np.array(x1 + x2 - s1 - 5)

def h2(x1,x2,s2):
    return np.array(2*x1 + 3*x2 + s2 - 12)

def h3(x1,x2,s1,s2):
    if (x1<=0) | (x2<=0) | (s1<=0) | (s2<=0): return False
    else: return True

# %%
# initial start point
x1 = 3; x2 = 2 ; s1 = 0; s2=0
print(f'x1={x1}, x2={x2}, s1={s1}, s2={s2}')
# Out:
# x1=3, x2=2, s1=0, s2=0

# %%
# define termination condition
epsilon = 0.1

# %% [markdown]
# step 2

# %%
var_ = ['x1','x2','s1','s2']

# %%
# basic / nonbasic variable
x=[x1,x2,s1,s2]
print( np.argsort(x)[::-1] )

# 0,1  / 2,3
x_j = x[:2]; x_c = [i for i in [x1,x2,s1,s2] if i not in x_j ]
print(f'x_j={x_j}, x_c={x_c}')
# Out:
# [0 1 3 2]
# x_j=[3, 2], x_c=[0, 0]

# %%
# define J, C

def deriv_h1(x, p):
    if x==var_[0]:
        x = symbols(var_[0])
        hx = x+x2+s1-5
    elif x==var_[1]:
        x = symbols(var_[1])
        hx = x1+x+s1-5
    else:
        x = symbols(var_[1])
        hx = x1+x2+x-5
    fprime = Derivative(hx, x).doit() # x에 대해서 미분
    return np.array(fprime.subs({x: p})).tolist()

def deriv_h2(x, p):
    if x==var_[0]:
        x = symbols(var_[0])
        hx = 2*x+3*x2+s2-12
    elif x==var_[1]:
        x = symbols(var_[1])
        hx = 2*x1+3*x+s2-12
    else:
        x = symbols(var_[1])
        hx = 2*x1+3*x2+x-12
    fprime = Derivative(hx, x).doit() # x에 대해서 미분
    return np.array(fprime.subs({x: p})).tolist()

# %%
J = np.array( [[deriv_h1(var_[0], x1),deriv_h1(var_[1], x2)], [deriv_h2(var_[0], x1),deriv_h2(var_[1], x2)]], dtype=np.float32 )
C = np.array( [[deriv_h1(var_[2], s1),deriv_h1(var_[3], s2)], [deriv_h2(var_[2], s1),deriv_h2(var_[3], s2)]], dtype=np.float32 )
print(J)
print(C)
# Out:
# [[1. 1.]
#  [2. 3.]]
# [[1. 1.]
#  [1. 1.]]

# %%
def deriv_f(x, p):
    if x==var_[0]:
        x = symbols(var_[0])
        fx = x*x + x2*x2 + 2*x*x2 + 3
    elif x==var_[1]:
        x = symbols(var_[1])
        fx = x1*x1 + x*x + 2*x1*x + 3
    fprime = Derivative(fx, x).doit() #x에 대해서 미분
    return np.array(fprime.subs({x: p})).tolist()

# %%
df_j = np.array( [deriv_f(var_[0], x1),deriv_f(var_[1], x2)] )
df_c = [0, 0]

# reduced gradient
r = df_c - df_j@np.linalg.inv(J)@np.array(C)

# %% [markdown]
# step 3

# %%
def l2_norm(x):
    return np.sqrt(float(np.sum(x**2)))

if l2_norm(r) > epsilon:
    # setting direction
    d_c = -r
    d_j = -np.linalg.inv(J)@C@d_c
    d = np.array(d_j.tolist() + d_c.tolist())

d
# Out:
# array([-40.0000000000000, 20.0000000000000, 10.0000000000000,
#        10.0000000000000], dtype=object)

# %% [markdown]
# step 4

# %%
alpha = 1; gamma = 0.8

# %%
# step 4-a
keep_go = True

while keep_go:

    print("\nStep 4-a start")
    v = [3,2,0,0] + alpha*d

    print(v)

    if (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2],v[3]):
        print('go to 4-d')
        break
    else:
        print('go to 4-b')


    # step 4-b
    print("\nStep 4-b start")
    v_j = v[:2]
    v_j -= np.array( [[deriv_h1(var_[0], v[0]),deriv_h1(var_[1], v[1])], [deriv_h2(var_[0], v[0]),deriv_h2(var_[1], v[1])]], dtype=np.float32 ) @ np.array([h1(v[0],v[1],v[2]), h2(v[0],v[1],v[3])], dtype=np.float32)
    v_c = v[2:]
    v_prev = dc(v)
    v[:2] = v_j
    print(v)

    # step 4-c
    print("\nStep 4-c start")
    if abs(l2_norm(v-v_prev)) > epsilon:
        print('go to 4-b')
    elif (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2], v[3]):
        print('go to 4-d')
        print(keep_go=False)
        print("???????")
    else:
        alpha *= gamma
        print('go to 4-a')
        print(f'alpha = {alpha}')
# Out:
# Step 4-a start
# [-37.0000000000000 22.0000000000000 10.0000000000000 10.0000000000000]
# go to 4-b
#
# Step 4-b start
# [3.00000000000000 112.000000000000 10.0000000000000 10.0000000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.8
#
# Step 4-a start
# [-29.0000000000000 18.0000000000000 8.00000000000000 8.00000000000000]
# go to 4-b
#
# Step 4-b start
# [3.00000000000000 90.0000000000000 8.00000000000000 8.00000000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.6400000000000001
#
# Step 4-a start
# [-22.6000000000000 14.8000000000000 6.40000000000000 6.40000000000000]
# go to 4-b
#
# Step 4-b start
# [3.00000038146972 72.4000022888184 6.40000000000000 6.40000000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.5120000000000001
#
# Step 4-a start
# [-17.4800000000000 12.2400000000000 5.12000000000000 5.12000000000000]
# go to 4-b
#
# Step 4-b start
# [2.99999954223632 58.3199980163574 5.12000000000000 5.12000000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.40960000000000013
#
# Step 4-a start
# [-13.3840000000000 10.1920000000000 4.09600000000000 4.09600000000000]
# go to 4-b
#
# Step 4-b start
# [3.00000077819824 47.0559984130859 4.09600000000000 4.09600000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.32768000000000014
#
# Step 4-a start
# [-10.1072000000000 8.55360000000000 3.27680000000000 3.27680000000000]
# go to 4-b
#
# Step 4-b start
# [3.00000062255859 38.0447994934082 3.27680000000000 3.27680000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.2621440000000001
#
# Step 4-a start
# [-7.48576000000000 7.24288000000000 2.62144000000000 2.62144000000000]
# go to 4-b
#
# Step 4-b start
# [2.99999973510742 30.8358403576660 2.62144000000000 2.62144000000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.2097152000000001
#
# Step 4-a start
# [-5.38860800000000 6.19430400000000 2.09715200000000 2.09715200000000]
# go to 4-b
#
# Step 4-b start
# [2.99999997882080 25.0686726676025 2.09715200000000 2.09715200000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.1677721600000001
#
# Step 4-a start
# [-3.71088640000000 5.35544320000000 1.67772160000000 1.67772160000000]
# go to 4-b
#
# Step 4-b start
# [3.00000007842407 20.4549381340820 1.67772160000000 1.67772160000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.13421772800000006
#
# Step 4-a start
# [-2.36870912000000 4.68435456000000 1.34217728000000 1.34217728000000]
# go to 4-b
#
# Step 4-b start
# [2.99999996737182 16.7639501257959 1.34217728000000 1.34217728000000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.10737418240000006
#
# Step 4-a start
# [-1.29496729600000 4.14748364800000 1.07374182400000 1.07374182400000]
# go to 4-b
#
# Step 4-b start
# [2.99999987853003 13.8111599099019 1.07374182400000 1.07374182400000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.08589934592000005
#
# Step 4-a start
# [-0.435973836800002 3.71798691840000 0.858993459200000 0.858993459200000]
# go to 4-b
#
# Step 4-b start
# [3.00000004587517 11.4489277371866 0.858993459200000 0.858993459200000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.06871947673600004
#
# Step 4-a start
# [0.251220930559998 3.37438953472000 0.687194767360000 0.687194767360000]
# go to 4-b
#
# Step 4-b start
# [2.99999998901642 9.55914199901443 0.687194767360000 0.687194767360000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.054975581388800036
#
# Step 4-a start
# [0.800976744447999 3.09951162777600 0.549755813888000 0.549755813888000]
# go to 4-b
#
# Step 4-b start
# [2.99999999121314 8.04731417141614 0.549755813888000 0.549755813888000]
#
# Step 4-c start
# go to 4-a
# alpha = 0.043980465111040035
#
# Step 4-a start
# [1.24078139555840 2.87960930222080 0.439804651110400 0.439804651110400]
# go to 4-b
#
# Step 4-b start
# [2.99999996912865 6.83785100334690 0.439804651110400 0.439804651110400]
#
# Step 4-c start
# go to 4-a
# alpha = 0.03518437208883203
#
# Step 4-a start
# [1.59262511644672 2.70368744177664 0.351843720888320 0.351843720888320]
# go to 4-b
#
# Step 4-b start
# [2.99999997530292 5.87028099341238 0.351843720888320 0.351843720888320]
#
# Step 4-c start
# go to 4-a
# alpha = 0.028147497671065627
#
# Step 4-a start
# [1.87410009315738 2.56294995342131 0.281474976710656 0.281474976710656]
# go to 4-b
#
# Step 4-b start
# [3.00000000408419 5.09622460399504 0.281474976710656 0.281474976710656]
#
# Step 4-c start
# go to 4-a
# alpha = 0.022517998136852502
#
# Step 4-a start
# [2.09928007452590 2.45035996273705 0.225179981368525 0.225179981368525]
# go to 4-b
#
# Step 4-b start
# [3.00000001518828 4.47697987393090 0.225179981368525 0.225179981368525]
#
# Step 4-c start
# go to 4-a
# alpha = 0.018014398509482003
#
# Step 4-a start
# [2.27942405962072 2.36028797018964 0.180143985094820 0.180143985094820]
# go to 4-b
#
# Step 4-b start
# [2.99999998830877 3.98158389914472 0.180143985094820 0.180143985094820]
#
# Step 4-c start
# go to 4-a
# alpha = 0.014411518807585602
#
# Step 4-a start
# [2.42353924769658 2.28823037615171 0.144115188075856 0.144115188075856]
# go to 4-b
#
# Step 4-b start
# [3.00000002640980 3.58526702394834 0.144115188075856 0.144115188075856]
#
# Step 4-c start
# go to 4-a
# alpha = 0.011529215046068483
#
# Step 4-a start
# [2.53883139815726 2.23058430092137 0.115292150460685 0.115292150460685]
# go to 4-b
#
# Step 4-b start
# [2.99999998536505 3.26821366684239 0.115292150460685 0.115292150460685]
#
# Step 4-c start
# go to 4-a
# alpha = 0.009223372036854787
#
# Step 4-a start
# [2.63106511852581 2.18446744073710 0.0922337203685479 0.0922337203685479]
# go to 4-b
#
# Step 4-b start
# [2.99999998829204 3.01457089771113 0.0922337203685479 0.0922337203685479]
#
# Step 4-c start
# go to 4-a
# alpha = 0.00737869762948383
#
# Step 4-a start
# [2.70485209482065 2.14757395258968 0.0737869762948383 0.0737869762948383]
# go to 4-b
#
# Step 4-b start
# [2.99999999063363 2.81165671816890 0.0737869762948383 0.0737869762948383]
#
# Step 4-c start
# go to 4-a
# alpha = 0.005902958103587064
#
# Step 4-a start
# [2.76388167585652 2.11805916207174 0.0590295810358706 0.0590295810358706]
# go to 4-b
#
# Step 4-b start
# [2.99999999250691 2.64932537453512 0.0590295810358706 0.0590295810358706]
#
# Step 4-c start
# go to 4-a
# alpha = 0.004722366482869652
#
# Step 4-a start
# [2.81110534068521 2.09444732965739 0.0472236648286965 0.0472236648286965]
# go to 4-b
#
# Step 4-b start
# [2.99999999996599 2.51946033539088 0.0472236648286965 0.0472236648286965]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0037778931862957215
#
# Step 4-a start
# [2.84888427254817 2.07555786372591 0.0377789318629572 0.0377789318629572]
# go to 4-b
#
# Step 4-b start
# [3.00000000295302 2.41556826831271 0.0377789318629572 0.0377789318629572]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0030223145490365774
#
# Step 4-a start
# [2.87910741803854 2.06044629098073 0.0302231454903658 0.0302231454903658]
# go to 4-d

# %%
# step 4-d
print(f'previous: {f(3,2)}, now: {f(v[0],v[1])}')
if f(3,2) <= f(v[0],v[1]):
    print("not optimized")
    # go to step 4-a
    alpha *= gamma
else:
    print('optimized! go to step2')
    print(v)
# Out:
# previous: 28, now: 27.3991908442860
# optimized! go to step2
# [2.87910741803854 2.06044629098073 0.0302231454903658 0.0302231454903658]

# %% [markdown]
# repeat until convergence

# %%
# step 2
# basic / nonbasic variable
x=dc(v)
print(x)
print( np.argsort(v)[::-1] )

# 0,1  / 2,3
x_j = x[:2]; x_c = [i for i in x if i not in x_j ]
print(f'x_j={x_j}, x_c={x_c}')
J = np.array( [[deriv_h1(var_[0], x[0]),deriv_h1(var_[1], x[1])], [deriv_h2(var_[0], x[0]),deriv_h2(var_[1], x[1])]], dtype=np.float32 )
C = np.array( [[deriv_h1(var_[2], x[2]),deriv_h1(var_[3], x[3])], [deriv_h2(var_[2], x[2]),deriv_h2(var_[3], x[3])]], dtype=np.float32 )


df_j = np.array( [deriv_f(var_[0], x[0]),deriv_f(var_[1], x[1])] )
df_c = [0, 0]

# reduced gradient
r = df_c - df_j@np.linalg.inv(J)@np.array(C)

# step 3
if l2_norm(r) > epsilon:
    # setting direction
    d_c = -r
    d_j = -np.linalg.inv(J)@C@d_c
    d = np.array(d_j.tolist() + d_c.tolist())
    print(f'direction: {d}')
else:
    print('convergence!')
# Out:
# [2.87910741803854 2.06044629098073 0.0302231454903658 0.0302231454903658]
# [0 1 3 2]
# x_j=[2.87910741803854 2.06044629098073], x_c=[0.0302231454903658, 0.0302231454903658]
# direction: [-37.5821483607707 18.7910741803854 9.39553709019268 9.39553709019268]

# %%
# step 4
alpha = 1; gamma = 0.8
# step 4-a
keep_go = True

while keep_go:

    print("\nStep 4-a start")
    v = x + alpha*d

    print(v)

    if (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2],v[3]):
        print('go to 4-d')
        break
    else:
        print('go to 4-b')


    # step 4-b
    print("\nStep 4-b start")
    v_j = v[:2]
    v_j -= np.array( [[deriv_h1(var_[0], v[0]),deriv_h1(var_[1], v[1])], [deriv_h2(var_[0], v[0]),deriv_h2(var_[1], v[1])]], dtype=np.float32 ) @ np.array([h1(v[0],v[1],v[2]), h2(v[0],v[1],v[3])], dtype=np.float32)
    v_c = v[2:]
    v_prev = dc(v)
    v[:2] = v_j
    print(v)

    # step 4-c
    print("\nStep 4-c start")
    if abs(l2_norm(v-v_prev)) > epsilon:
        print('go to 4-b')
    elif (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2], v[3]):
        print('go to 4-d')
        print(keep_go=False)
    else:
        alpha *= gamma
        print('go to 4-a')
        print(f'alpha = {alpha}')
# Out:
# Step 4-a start
# [-34.7030409427322 20.8515204713661 9.42576023568305 9.42576023568305]
# go to 4-b
#
# Step 4-b start
# [3.00000013392796 105.683360986503 9.42576023568305 9.42576023568305]
#
# Step 4-c start
# go to 4-a
# alpha = 0.8
#
# Step 4-a start
# [-27.1866112705780 17.0933056352890 7.54665281764451 7.54665281764451]
# go to 4-b
#
# Step 4-b start
# [2.99999990495906 85.0131817339218 7.54665281764451 7.54665281764451]
#
# Step 4-c start
# go to 4-a
# alpha = 0.6400000000000001
#
# Step 4-a start
# [-21.1734675328547 14.0867337664274 6.04336688321368 6.04336688321368]
# go to 4-b
#
# Step 4-b start
# [3.00000010325366 68.4770345171598 6.04336688321368 6.04336688321368]
#
# Step 4-c start
# go to 4-a
# alpha = 0.5120000000000001
#
# Step 4-a start
# [-16.3629525426761 11.6814762713380 4.84073813566902 4.84073813566902]
# go to 4-b
#
# Step 4-b start
# [3.00000064335907 55.2481190325685 4.84073813566902 4.84073813566902]
#
# Step 4-c start
# go to 4-a
# alpha = 0.40960000000000013
#
# Step 4-a start
# [-12.5145405505332 9.75727027526658 3.87863513763329 3.87863513763329]
# go to 4-b
#
# Step 4-b start
# [3.00000012176909 44.6649851190166 3.87863513763329 3.87863513763329]
#
# Step 4-c start
# go to 4-a
# alpha = 0.32768000000000014
#
# Step 4-a start
# [-9.43581095681882 8.21790547840941 3.10895273920471 3.10895273920471]
# go to 4-b
#
# Step 4-b start
# [3.00000008596682 36.1984810399328 3.10895273920471 3.10895273920471]
#
# Step 4-c start
# go to 4-a
# alpha = 0.2621440000000001
#
# Step 4-a start
# [-6.97282728184735 6.98641364092367 2.49320682046184 2.49320682046184]
# go to 4-b
#
# Step 4-b start
# [2.99999967585529 29.4252754878475 2.49320682046184 2.49320682046184]
#
# Step 4-c start
# go to 4-a
# alpha = 0.2097152000000001
#
# Step 4-a start
# [-5.00244034187017 6.00122017093509 2.00061008546754 2.00061008546754]
# go to 4-b
#
# Step 4-b start
# [3.00000011070551 24.0067095203003 2.00061008546754 2.00061008546754]
#
# Step 4-c start
# go to 4-a
# alpha = 0.1677721600000001
#
# Step 4-a start
# [-3.42613078988843 5.21306539494422 1.60653269747211 1.60653269747211]
# go to 4-b
#
# Step 4-b start
# [2.99999998174853 19.6718599887553 1.60653269747211 1.60653269747211]
#
# Step 4-c start
# go to 4-a
# alpha = 0.13421772800000006
#
# Step 4-a start
# [-2.16508314830304 4.58254157415152 1.29127078707576 1.29127078707576]
# go to 4-b
#
# Step 4-b start
# [2.99999978321552 16.2039786469054 1.29127078707576 1.29127078707576]
#
# Step 4-c start
# go to 4-a
# alpha = 0.10737418240000006
#
# Step 4-a start
# [-1.15624503503472 4.07812251751736 1.03906125875868 1.03906125875868]
# go to 4-b
#
# Step 4-b start
# [3.00000019659370 13.4296735734256 1.03906125875868 1.03906125875868]
#
# Step 4-c start
# go to 4-a
# alpha = 0.08589934592000005
#
# Step 4-a start
# [-0.349174544420071 3.67458727221004 0.837293636105018 0.837293636105018]
# go to 4-b
#
# Step 4-b start
# [2.99999995509165 11.2102298961114 0.837293636105018 0.837293636105018]
#
# Step 4-c start
# go to 4-a
# alpha = 0.06871947673600004
#
# Step 4-a start
# [0.296481848071651 3.35175907596417 0.675879537982087 0.675879537982087]
# go to 4-b
#
# Step 4-b start
# [3.00000000030859 9.43467533572980 0.675879537982087 0.675879537982087]
#
# Step 4-c start
# go to 4-a
# alpha = 0.054975581388800036
#
# Step 4-a start
# [0.813006962065028 3.09349651896749 0.546748259483743 0.546748259483743]
# go to 4-b
#
# Step 4-b start
# [3.00000008416586 8.01423092448506 0.546748259483743 0.546748259483743]
#
# Step 4-c start
# go to 4-a
# alpha = 0.043980465111040035
#
# Step 4-a start
# [1.22622705325973 2.88688647337014 0.443443236685068 0.443443236685068]
# go to 4-b
#
# Step 4-b start
# [3.00000000820053 6.87787544317299 0.443443236685068 0.443443236685068]
#
# Step 4-c start
# go to 4-a
# alpha = 0.03518437208883203
#
# Step 4-a start
# [1.55680312621549 2.72159843689226 0.360799218446127 0.360799218446127]
# go to 4-b
#
# Step 4-b start
# [3.00000001895383 5.96879153496049 0.360799218446127 0.360799218446127]
#
# Step 4-c start
# go to 4-a
# alpha = 0.028147497671065627
#
# Step 4-a start
# [1.82126398458010 2.58936800770995 0.294684003854975 0.294684003854975]
# go to 4-b
#
# Step 4-b start
# [2.99999995603091 5.24152412228820 0.294684003854975 0.294684003854975]
#
# Step 4-c start
# go to 4-a
# alpha = 0.022517998136852502
#
# Step 4-a start
# [2.03283267127179 2.48358366436411 0.241791832182053 0.241791832182053]
# go to 4-b
#
# Step 4-b start
# [2.99999998913907 4.65971014446665 0.241791832182053 0.241791832182053]
#
# Step 4-c start
# go to 4-a
# alpha = 0.018014398509482003
#
# Step 4-a start
# [2.20208762062514 2.39895618968743 0.199478094843716 0.199478094843716]
# go to 4-b
#
# Step 4-b start
# [2.99999997986281 4.19425905757684 0.199478094843716 0.199478094843716]
#
# Step 4-c start
# go to 4-a
# alpha = 0.014411518807585602
#
# Step 4-a start
# [2.33749158010782 2.33125420994609 0.165627104973046 0.165627104973046]
# go to 4-b
#
# Step 4-b start
# [3.00000000820459 3.82189818806499 0.165627104973046 0.165627104973046]
#
# Step 4-c start
# go to 4-a
# alpha = 0.011529215046068483
#
# Step 4-a start
# [2.44581474769396 2.27709262615302 0.138546313076510 0.138546313076510]
# go to 4-b
#
# Step 4-b start
# [3.00000001895708 3.52400951629737 0.138546313076510 0.138546313076510]
#
# Step 4-c start
# go to 4-a
# alpha = 0.009223372036854787
#
# Step 4-a start
# [2.53247328176288 2.23376335911856 0.116881679559281 0.116881679559281]
# go to 4-b
#
# Step 4-b start
# [2.99999998583583 3.28569843583212 0.116881679559281 0.116881679559281]
#
# Step 4-c start
# go to 4-a
# alpha = 0.00737869762948383
#
# Step 4-a start
# [2.60180010901801 2.19909994549100 0.0995499727454979 0.0995499727454979]
# go to 4-b
#
# Step 4-b start
# [2.99999999510161 3.09504966682736 0.0995499727454979 0.0995499727454979]
#
# Step 4-c start
# go to 4-a
# alpha = 0.005902958103587064
#
# Step 4-a start
# [2.65726157082211 2.17136921458894 0.0856846072944715 0.0856846072944715]
# go to 4-b
#
# Step 4-b start
# [2.99999999059331 2.94253065162355 0.0856846072944715 0.0856846072944715]
#
# Step 4-c start
# go to 4-a
# alpha = 0.004722366482869652
#
# Step 4-a start
# [2.70163074026540 2.14918462986730 0.0745923149336504 0.0745923149336504]
# go to 4-b
#
# Step 4-b start
# [2.99999999890760 2.82051543946050 0.0745923149336504 0.0745923149336504]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0037778931862957215
#
# Step 4-a start
# [2.73712607582003 2.13143696208999 0.0657184810449934 0.0657184810449934]
# go to 4-b
#
# Step 4-b start
# [2.99999999363810 2.72290326973006 0.0657184810449934 0.0657184810449934]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0030223145490365774
#
# Step 4-a start
# [2.76552234426373 2.11723882786814 0.0586194139340679 0.0586194139340679]
# go to 4-b
#
# Step 4-b start
# [2.99999999836319 2.64481354586664 0.0586194139340679 0.0586194139340679]
#
# Step 4-c start
# go to 4-a
# alpha = 0.002417851639229262
#
# Step 4-a start
# [2.78823935901869 2.10588032049066 0.0529401602453275 0.0529401602453275]
# go to 4-b
#
# Step 4-b start
# [2.99999999916304 2.58234176081544 0.0529401602453275 0.0529401602453275]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0019342813113834097
#
# Step 4-a start
# [2.80641297082266 2.09679351458867 0.0483967572943351 0.0483967572943351]
# go to 4-b
#
# Step 4-b start
# [3.00000000576338 2.53236432085355 0.0483967572943351 0.0483967572943351]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0015474250491067279
#
# Step 4-a start
# [2.82095186026583 2.08952406986708 0.0447620349335413 0.0447620349335413]
# go to 4-b
#
# Step 4-b start
# [2.99999999614249 2.49238238676543 0.0447620349335413 0.0447620349335413]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0012379400392853823
#
# Step 4-a start
# [2.83258297182038 2.08370851408981 0.0418542570449062 0.0418542570449062]
# go to 4-b
#
# Step 4-b start
# [3.00000000632717 2.46039681565308 0.0418542570449062 0.0418542570449062]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0009903520314283058
#
# Step 4-a start
# [2.84188786106401 2.07905606946800 0.0395280347339981 0.0395280347339981]
# go to 4-b
#
# Step 4-b start
# [2.99999999957376 2.43480838856552 0.0395280347339981 0.0395280347339981]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0007922816251426447
#
# Step 4-a start
# [2.84933177245891 2.07533411377054 0.0376670568852716 0.0376670568852716]
# go to 4-b
#
# Step 4-b start
# [3.00000000609195 2.41433761709314 0.0376670568852716 0.0376670568852716]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0006338253001141158
#
# Step 4-a start
# [2.85528690157484 2.07235654921258 0.0361782746062905 0.0361782746062905]
# go to 4-b
#
# Step 4-b start
# [3.00000000534605 2.39796101779664 0.0361782746062905 0.0361782746062905]
#
# Step 4-c start
# go to 4-a
# alpha = 0.0005070602400912927
#
# Step 4-a start
# [2.86005100486758 2.06997449756621 0.0349872487831055 0.0349872487831055]
# go to 4-b
#
# Step 4-b start
# [2.99999999878886 2.38485972643851 0.0349872487831055 0.0349872487831055]
#
# Step 4-c start
# go to 4-a
# alpha = 0.00040564819207303417
#
# Step 4-a start
# [2.86386228750177 2.06806885624912 0.0340344281245576 0.0340344281245576]
# go to 4-b
#
# Step 4-b start
# [2.99999999652334 2.37437870527293 0.0340344281245576 0.0340344281245576]
#
# Step 4-c start
# go to 4-a
# alpha = 0.00032451855365842736
#
# Step 4-a start
# [2.86691131360912 2.06654434319544 0.0332721715977192 0.0332721715977192]
# go to 4-d

# %%
# step 4-d
print(f'previous: {f(3,2)}, now: {f(v[0],v[1])}')
if f(3,2) <= f(v[0],v[1]):
    print("\nnot optimized")
    # go to step 4-a
    alpha *= gamma
else:
    print('\noptimized! go to step2')
    print(v)
# Out:
# previous: 28, now: 27.3389847176569
#
# optimized! go to step2
# [2.86691131360912 2.06654434319544 0.0332721715977192 0.0332721715977192]

# %%
real_go = True
while real_go:
    # step 2
    # basic / nonbasic variable
    x=dc(v)
    print(x)
    print( np.argsort(v)[::-1] )

    # 0,1  / 2,3
    x_j = x[:2]; x_c = [i for i in x if i not in x_j ]
    print(f'x_j={x_j}, x_c={x_c}')
    J = np.array( [[deriv_h1(var_[0], x[0]),deriv_h1(var_[1], x[1])], [deriv_h2(var_[0], x[0]),deriv_h2(var_[1], x[1])]], dtype=np.float32 )
    C = np.array( [[deriv_h1(var_[2], x[2]),deriv_h1(var_[3], x[3])], [deriv_h2(var_[2], x[2]),deriv_h2(var_[3], x[3])]], dtype=np.float32 )


    df_j = np.array( [deriv_f(var_[0], x[0]),deriv_f(var_[1], x[1])] )
    df_c = [0, 0]

    # reduced gradient
    r = df_c - df_j@np.linalg.inv(J)@np.array(C)

    # step 3
    if l2_norm(r) > epsilon:
        # setting direction
        d_c = -r
        d_j = -np.linalg.inv(J)@C@d_c
        d = np.array(d_j.tolist() + d_c.tolist())
        print(f'direction: {d}')
    else:
        print('convergence!')
        real_go = False
        break

    # step 4
    alpha = 1; gamma = 0.8
    # step 4-a
    keep_go = True

    while keep_go:

        print("\nStep 4-a start")
        v = x + alpha*d

        print(v)

        if (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2],v[3]):
            print('go to 4-d')
            break
        else:
            print('go to 4-b')


        # step 4-b
        print("\nStep 4-b start")
        v_j = v[:2]
        v_j -= np.array( [[deriv_h1(var_[0], v[0]),deriv_h1(var_[1], v[1])], [deriv_h2(var_[0], v[0]),deriv_h2(var_[1], v[1])]], dtype=np.float32 ) @ np.array([h1(v[0],v[1],v[2]), h2(v[0],v[1],v[3])], dtype=np.float32)
        v_c = v[2:]
        v_prev = dc(v)
        v[:2] = v_j
        print(v)

        # step 4-c
        print("\nStep 4-c start")
        if abs(l2_norm(v-v_prev)) > epsilon:
            print('go to 4-b')
        elif (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2], v[3]):
            print('go to 4-d')
            print(keep_go=False)
        else:
            alpha *= gamma
            print('go to 4-a')
            print(f'alpha = {alpha}')

    step4_d = True
    while step4_d:
        # step 4-d
        print(f'previous: {f(3,2)}, now: {f(v[0],v[1])}')
        if f(3,2) <= f(v[0],v[1]):
            print("\nnot optimized")
            # go to step 4-a
            alpha *= gamma
        else:
            print('\noptimized! go to step2')
            print(v)
            step4_d = False
            keep_go = False

        while keep_go:

            print("\nStep 4-a start")
            v = x + alpha*d

            print(v)

            if (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2],v[3]):
                print('go to 4-d')
                break
            else:
                print('go to 4-b')


            # step 4-b
            print("\nStep 4-b start")
            v_j = v[:2]
            v_j -= np.array( [[deriv_h1(var_[0], v[0]),deriv_h1(var_[1], v[1])], [deriv_h2(var_[0], v[0]),deriv_h2(var_[1], v[1])]], dtype=np.float32 ) @ np.array([h1(v[0],v[1],v[2]), h2(v[0],v[1],v[3])], dtype=np.float32)
            v_c = v[2:]
            v_prev = dc(v)
            v[:2] = v_j
            print(v)

            # step 4-c
            print("\nStep 4-c start")
            if abs(l2_norm(v-v_prev)) > epsilon:
                print('go to 4-b')
            elif (abs( h1(v[0],v[1],v[2]) ) <= epsilon) & (abs( h2(v[0],v[1],v[3]) ) <= epsilon) & h3(v[0],v[1],v[2], v[3]):
                print('go to 4-d')
                print(keep_go=False)
            else:
                alpha *= gamma
                print('go to 4-a')
                print(f'alpha = {alpha}')

# %%
x=dc(v)

# %%
print(x)
print( f(x[0],x[1]) )

print( h1(x[0],x[1],x[2]) )
print( h2(x[0],x[1],x[3]) )
